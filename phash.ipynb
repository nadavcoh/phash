# %%
import os
from PIL import Image
import imagehash
from pillow_heif import register_heif_opener
register_heif_opener()

# %%
import datetime

# %%
img1 = Image.open("img/pic1.jpg")
img1.info
# Out:
# {'jfif': 257,
#  'jfif_version': (1, 1),
#  'jfif_unit': 0,
#  'jfif_density': (1, 1),
#  'progressive': 1,
#  'progression': 1}

# %%
img2 = Image.open("img/pic2.heic")
img2.info
# Out:
# {'primary': True,
#  'bit_depth': 8,
# ...

# %%
print(img1.getexif())
# Out:
# {}

# %%
a=os.path.getmtime("img/pic1.jpg")

# %%
os.stat("img/pic1.jpg")
# Out:
# os.stat_result(st_mode=33188, st_ino=8737158137, st_dev=16777222, st_nlink=1, st_uid=501, st_gid=20, st_size=305377, st_atime=1705700239, st_mtime=1705695583, st_ctime=1705700238)

# %%
datetime.datetime.utcfromtimestamp(a).year
# Out:
# /var/folders/zn/1yxhwxvn24x2c0k9zjfmyxpc0000gn/T/ipykernel_83969/2242201196.py:1: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   datetime.datetime.utcfromtimestamp(a).year
# 2024
